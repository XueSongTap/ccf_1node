# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt1
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import matplotlib.pyplot as plt3
import matplotlib.pyplot as plt4
import matplotlib.pyplot as plt5

df = pd.read_csv("data_raw.csv",encoding="GB2312")
df2 = pd.read_csv("data_filter.csv",encoding="GB2312")

# %%
plt.ylim((-180,180))
plt.scatter(df['%time'], df['field.vector.x'])
plt.show()

# %%
plt1.ylim((-180,180))
plt1.scatter(df2['%time'], df2['field.vector.x'])
plt1.show()

# %%
plt2.ylim((-180,180))

plt2.scatter(df['%time'], df['field.vector.y'])
plt2.show()

# %%
plt3.ylim((-180,180))
plt3.scatter(df2['%time'], df2['field.vector.y'])
plt3.show()

# %%
plt4.ylim((-180,180))

plt4.scatter(df['%time'], df['field.vector.z'])
plt4.show()

# %%
plt5.ylim((-180,180))

plt5.scatter(df2['%time'], df2['field.vector.z'])
plt5.show()
